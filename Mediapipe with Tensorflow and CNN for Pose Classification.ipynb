# %% [markdown]
# # Installing Packages

# %%
# !pip install tensorflow
# Out:
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4848 sha256=553ac4eb15e7159cd6c9df12083ce2065c598139dbb438fb56efe762586cd6be
#   Stored in directory: c:\users\faisal\appdata\local\pip\cache\wheels\b6\0d\90\0d1bbd99855f99cb2f6c2e5ff96f8023fad8ec367695f7d72d
# Successfully built termcolor
# ...

# %%
# !pip install keras

# %% [markdown]
# # Importing Libraries

# %%
# !pip install pandas

# %%
# !pip install mediapipe

# %%
# !pip install matplotlib

# %%
# !pip install numpy

# %%
# !pip install csv
# Out:
# ERROR: Could not find a version that satisfies the requirement csv (from versions: none)
# ERROR: No matching distribution found for csv

# %%
# Import the much needed stuff for training
import pandas as pd
import numpy as np
import keras
import tensorflow as tf
import mediapipe as mp
import os
import csv
import cv2 as cv
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Make numpy values easier to read.
np.set_printoptions(precision=3, suppress=True)

# Checking Tensorflow Version
tf.__version__
# Out:
# '2.9.1'

# %%
# Import the much needed stuff for training
import pandas as pd
import numpy as np
import keras
import tensorflow as tf
import mediapipe as mp
import os
import csv
import cv2 as cv
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Make numpy values easier to read.
np.set_printoptions(precision=3, suppress=True)

# Checking Tensorflow Version
tf.__version__
# Out:
# '2.8.0'

# %%
from mediapipe.python.solutions import drawing_utils as mp_drawing
from mediapipe.python.solutions import pose as mp_pose
from tensorflow.keras.utils import to_categorical
from mediapipe.framework.formats import landmark_pb2
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %%
# Function to Extract Feature from images or Frame
def extract_feature(input_image):
    mp_drawing = mp.solutions.drawing_utils
    mp_pose = mp.solutions.pose
    image = cv.imread(input_image)
    with mp_pose.Pose(min_detection_confidence=0.5,min_tracking_confidence=0.5) as pose:
        results = pose.process(image)
        image_height, image_width, _c = image.shape
        if not results.pose_landmarks:
            LEFT_EYE_INNER_X=0
            LEFT_EYE_INNER_Y=0
            LEFT_EYE_INNER_Z=0
            LEFT_EYE_X=0
            LEFT_EYE_Y=0
            LEFT_EYE_Z=0
            LEFT_EYE_OUTER_X=0
            LEFT_EYE_OUTER_Y=0
            LEFT_EYE_OUTER_Z=0
            RIGHT_EYE_INNER_X=0
            RIGHT_EYE_INNER_Y=0
            RIGHT_EYE_INNER_Z=0
            RIGHT_EYE_X=0
            RIGHT_EYE_Y=0
            RIGHT_EYE_Z=0
            RIGHT_EYE_OUTER_X=0
            RIGHT_EYE_OUTER_Y=0
            RIGHT_EYE_OUTER_Z=0
            LEFT_EAR_X=0
            LEFT_EAR_Y=0
            LEFT_EAR_Z=0
            RIGHT_EAR_X=0
            RIGHT_EAR_Y=0
            RIGHT_EAR_Z=0
            MOUTH_LEFT_X=0
            MOUTH_LEFT_Y=0
            MOUTH_LEFT_Z=0
            MOUTH_RIGHT_X=0
            MOUTH_RIGHT_Y=0
            MOUTH_RIGHT_Z=0
            LeftShoulder_X=0
            LeftShoulder_Y=0
            LeftShoulder_Z=0
            RIGHT_SHOULDER_X=0
            RIGHT_SHOULDER_Y=0
            RIGHT_SHOULDER_Z=0
            LEFT_ELBOW_X=0
            LEFT_ELBOW_Y=0
            LEFT_ELBOW_Z=0
            RIGHT_ELBOW_X=0
            RIGHT_ELBOW_Y=0
            RIGHT_ELBOW_Z=0
            LEFT_WRIST_X=0
            LEFT_WRIST_Y=0
            LEFT_WRIST_Z=0
            RIGHT_WRIST_X=0
            RIGHT_WRIST_Y=0
            RIGHT_WRIST_Z=0
            LEFT_PINKY_X=0
            LEFT_PINKY_Y=0
            LEFT_PINKY_Z=0
            RIGHT_PINKY_X=0
            RIGHT_PINKY_Y=0
            RIGHT_PINKY_Z=0
            LEFT_INDEX_X=0
            LEFT_INDEX_Y=0
            LEFT_INDEX_Z=0
            RIGHT_INDEX_X=0
            RIGHT_INDEX_Y=0
            RIGHT_INDEX_Z=0
            LEFT_THUMB_X=0
            LEFT_THUMB_Y=0
            LEFT_THUMB_Z=0
            RIGHT_THUMB_X=0
            RIGHT_THUMB_Y=0
            RIGHT_THUMB_Z=0
            LEFT_HIP_X=0
            LEFT_HIP_Y=0
            LEFT_HIP_Z=0
            RIGHT_HIP_X=0
            RIGHT_HIP_Y=0
            RIGHT_HIP_Z=0
            LEFT_KNEE_X=0
            LEFT_KNEE_Y=0
            LEFT_KNEE_Z=0
            RIGHT_KNEE_X=0
            RIGHT_KNEE_Y=0
            RIGHT_KNEE_Z=0
            LEFT_ANKLE_X=0
            LEFT_ANKLE_Y=0
            LEFT_ANKLE_Z=0
            RIGHT_ANKLE_X=0
            RIGHT_ANKLE_Y=0
            RIGHT_ANKLE_Z=0
            LEFT_HEEL_X=0
            LEFT_HEEL_Y=0
            LEFT_HEEL_Z=0
            RIGHT_HEEL_X=0
            RIGHT_HEEL_Y=0
            RIGHT_HEEL_Z=0
            LEFT_FOOT_INDEX_X=0
            LEFT_FOOT_INDEX_Y=0
            LEFT_FOOT_INDEX_Z=0
            RIGHT_FOOT_INDEX_X=0
            RIGHT_FOOT_INDEX_Y=0
            RIGHT_FOOT_INDEX_Z=0
                
                # Set image to Zero
            annotated_image = 0

                # Return Whole Landmark and Image
            return (LEFT_EYE_INNER_X, LEFT_EYE_INNER_Y, LEFT_EYE_INNER_Z,
                        LEFT_EYE_X, LEFT_EYE_Y, LEFT_EYE_Z,
                        LEFT_EYE_OUTER_X, LEFT_EYE_OUTER_Y, LEFT_EYE_OUTER_Z,
                        RIGHT_EYE_INNER_X, RIGHT_EYE_INNER_Y, RIGHT_EYE_INNER_Z,
                        RIGHT_EYE_X, RIGHT_EYE_Y, RIGHT_EYE_Z,
                        RIGHT_EYE_OUTER_X, RIGHT_EYE_OUTER_Y, RIGHT_EYE_OUTER_Z,
                        LEFT_EAR_X, LEFT_EAR_Y, LEFT_EAR_Z,
                        RIGHT_EAR_X, RIGHT_EAR_Y, RIGHT_EAR_Z,
                        MOUTH_LEFT_X, MOUTH_LEFT_Y, MOUTH_LEFT_Z,
                        MOUTH_RIGHT_X, MOUTH_RIGHT_Y, MOUTH_RIGHT_Z,
                        LeftShoulder_X, LeftShoulder_Y, LeftShoulder_Z,
                        RIGHT_SHOULDER_X, RIGHT_SHOULDER_Y, RIGHT_SHOULDER_Z,
                        LEFT_ELBOW_X, LEFT_ELBOW_Y, LEFT_ELBOW_Z,
                        RIGHT_ELBOW_X, RIGHT_ELBOW_Y, RIGHT_ELBOW_Z,
                        LEFT_WRIST_X, LEFT_WRIST_Y, LEFT_WRIST_Z,
                        RIGHT_WRIST_X, RIGHT_WRIST_Y, RIGHT_WRIST_Z,
                        LEFT_PINKY_X, LEFT_PINKY_Y, LEFT_PINKY_Z,
                        RIGHT_PINKY_X, RIGHT_PINKY_Y, RIGHT_PINKY_Z,
                        LEFT_INDEX_X, LEFT_INDEX_Y, LEFT_INDEX_Z,
                        RIGHT_INDEX_X, RIGHT_INDEX_Y, RIGHT_INDEX_Z,
                        LEFT_THUMB_X, LEFT_THUMB_Y, LEFT_THUMB_Z,
                        RIGHT_THUMB_X, RIGHT_THUMB_Y, RIGHT_THUMB_Z,
                        LEFT_HIP_X, LEFT_HIP_Y, LEFT_HIP_Z,
                        RIGHT_HIP_X, RIGHT_HIP_Y, RIGHT_HIP_Z,
                        LEFT_KNEE_X, LEFT_KNEE_Y, LEFT_KNEE_Z,
                        RIGHT_KNEE_X, RIGHT_KNEE_Y, RIGHT_KNEE_Z,
                        LEFT_ANKLE_X, LEFT_ANKLE_Y, LEFT_ANKLE_Z,
                        RIGHT_ANKLE_X, RIGHT_ANKLE_Y, RIGHT_ANKLE_Z,
                        LEFT_HEEL_X, LEFT_HEEL_Y, LEFT_HEEL_Z,
                        RIGHT_HEEL_X, RIGHT_HEEL_Y, RIGHT_HEEL_Z,
                        LEFT_FOOT_INDEX_X, LEFT_FOOT_INDEX_Y, LEFT_FOOT_INDEX_Z,
                        RIGHT_FOOT_INDEX_X, RIGHT_FOOT_INDEX_Y, RIGHT_FOOT_INDEX_Z,
                        annotated_image)
                        
            
        else:
            annotated_image = image.copy()
            LEFT_EYE_INNER_X=results.pose_landmarks.landmark[1].x*image_width
            LEFT_EYE_INNER_Y=results.pose_landmarks.landmark[1].y*image_height
            LEFT_EYE_INNER_Z=results.pose_landmarks.landmark[1].z

            LEFT_EYE_X=results.pose_landmarks.landmark[2].x*image_width
            LEFT_EYE_Y=results.pose_landmarks.landmark[2].y*image_height
            LEFT_EYE_Z=results.pose_landmarks.landmark[2].z

            LEFT_EYE_OUTER_X=results.pose_landmarks.landmark[3].x*image_width
            LEFT_EYE_OUTER_Y=results.pose_landmarks.landmark[3].y*image_height
            LEFT_EYE_OUTER_Z=results.pose_landmarks.landmark[3].z

            RIGHT_EYE_INNER_X=results.pose_landmarks.landmark[4].x*image_width
            RIGHT_EYE_INNER_Y=results.pose_landmarks.landmark[4].y*image_height
            RIGHT_EYE_INNER_Z=results.pose_landmarks.landmark[4].z

            RIGHT_EYE_X=results.pose_landmarks.landmark[5].x*image_width
            RIGHT_EYE_Y=results.pose_landmarks.landmark[5].y*image_height
            RIGHT_EYE_Z=results.pose_landmarks.landmark[5].z

            RIGHT_EYE_OUTER_X=results.pose_landmarks.landmark[6].x*image_width
            RIGHT_EYE_OUTER_Y=results.pose_landmarks.landmark[6].y*image_height
            RIGHT_EYE_OUTER_Z=results.pose_landmarks.landmark[6].z

            LEFT_EAR_X=results.pose_landmarks.landmark[7].x*image_width
            LEFT_EAR_Y=results.pose_landmarks.landmark[7].y*image_height
            LEFT_EAR_Z=results.pose_landmarks.landmark[7].z

            RIGHT_EAR_X=results.pose_landmarks.landmark[8].x*image_width
            RIGHT_EAR_Y=results.pose_landmarks.landmark[8].y*image_height
            RIGHT_EAR_Z=results.pose_landmarks.landmark[8].z

            MOUTH_LEFT_X=results.pose_landmarks.landmark[9].x*image_width
            MOUTH_LEFT_Y=results.pose_landmarks.landmark[9].y*image_height
            MOUTH_LEFT_Z=results.pose_landmarks.landmark[9].z

            MOUTH_RIGHT_X=results.pose_landmarks.landmark[10].x*image_width
            MOUTH_RIGHT_Y=results.pose_landmarks.landmark[10].y*image_height
            MOUTH_RIGHT_Z=results.pose_landmarks.landmark[10].z

            LeftShoulder_X=results.pose_landmarks.landmark[11].x*image_width
            LeftShoulder_Y=results.pose_landmarks.landmark[11].y*image_height
            LeftShoulder_Z=results.pose_landmarks.landmark[11].z

            RIGHT_SHOULDER_X=results.pose_landmarks.landmark[12].x*image_width
            RIGHT_SHOULDER_Y=results.pose_landmarks.landmark[12].y*image_height
            RIGHT_SHOULDER_Z=results.pose_landmarks.landmark[12].z

            LEFT_ELBOW_X=results.pose_landmarks.landmark[13].x*image_width
            LEFT_ELBOW_Y=results.pose_landmarks.landmark[13].y*image_height
            LEFT_ELBOW_Z=results.pose_landmarks.landmark[13].z

            RIGHT_ELBOW_X=results.pose_landmarks.landmark[14].x*image_width
            RIGHT_ELBOW_Y=results.pose_landmarks.landmark[14].y*image_height
            RIGHT_ELBOW_Z=results.pose_landmarks.landmark[14].z

            LEFT_WRIST_X=results.pose_landmarks.landmark[15].x*image_width
            LEFT_WRIST_Y=results.pose_landmarks.landmark[15].y*image_height
            LEFT_WRIST_Z=results.pose_landmarks.landmark[15].z

            RIGHT_WRIST_X=results.pose_landmarks.landmark[16].x*image_width
            RIGHT_WRIST_Y=results.pose_landmarks.landmark[16].y*image_height
            RIGHT_WRIST_Z=results.pose_landmarks.landmark[16].z

            LEFT_PINKY_X=results.pose_landmarks.landmark[17].x*image_width
            LEFT_PINKY_Y=results.pose_landmarks.landmark[17].y*image_height
            LEFT_PINKY_Z=results.pose_landmarks.landmark[17].z

            RIGHT_PINKY_X=results.pose_landmarks.landmark[18].x*image_width
            RIGHT_PINKY_Y=results.pose_landmarks.landmark[18].y*image_height
            RIGHT_PINKY_Z=results.pose_landmarks.landmark[18].z

            LEFT_INDEX_X=results.pose_landmarks.landmark[19].x*image_width
            LEFT_INDEX_Y=results.pose_landmarks.landmark[19].y*image_height
            LEFT_INDEX_Z=results.pose_landmarks.landmark[19].z

            RIGHT_INDEX_X=results.pose_landmarks.landmark[20].x*image_width
            RIGHT_INDEX_Y=results.pose_landmarks.landmark[20].y*image_height
            RIGHT_INDEX_Z=results.pose_landmarks.landmark[20].z

            LEFT_THUMB_X=results.pose_landmarks.landmark[21].x*image_width
            LEFT_THUMB_Y=results.pose_landmarks.landmark[21].y*image_height
            LEFT_THUMB_Z=results.pose_landmarks.landmark[21].z

            RIGHT_THUMB_X=results.pose_landmarks.landmark[22].x*image_width
            RIGHT_THUMB_Y=results.pose_landmarks.landmark[22].y*image_height
            RIGHT_THUMB_Z=results.pose_landmarks.landmark[22].z

            LEFT_HIP_X=results.pose_landmarks.landmark[23].x*image_width
            LEFT_HIP_Y=results.pose_landmarks.landmark[23].y*image_height
            LEFT_HIP_Z=results.pose_landmarks.landmark[23].z

            RIGHT_HIP_X=results.pose_landmarks.landmark[24].x*image_width
            RIGHT_HIP_Y=results.pose_landmarks.landmark[24].y*image_height
            RIGHT_HIP_Z=results.pose_landmarks.landmark[24].z

            LEFT_KNEE_X=results.pose_landmarks.landmark[25].x*image_width
            LEFT_KNEE_Y=results.pose_landmarks.landmark[25].y*image_height
            LEFT_KNEE_Z=results.pose_landmarks.landmark[25].z

            RIGHT_KNEE_X=results.pose_landmarks.landmark[26].x*image_width
            RIGHT_KNEE_Y=results.pose_landmarks.landmark[26].y*image_height
            RIGHT_KNEE_Z=results.pose_landmarks.landmark[26].z

            LEFT_ANKLE_X=results.pose_landmarks.landmark[27].x*image_width
            LEFT_ANKLE_Y=results.pose_landmarks.landmark[27].y*image_height
            LEFT_ANKLE_Z=results.pose_landmarks.landmark[27].z

            RIGHT_ANKLE_X=results.pose_landmarks.landmark[28].x*image_width
            RIGHT_ANKLE_Y=results.pose_landmarks.landmark[28].y*image_height
            RIGHT_ANKLE_Z=results.pose_landmarks.landmark[28].z

            LEFT_HEEL_X=results.pose_landmarks.landmark[29].x*image_width
            LEFT_HEEL_Y=results.pose_landmarks.landmark[29].y*image_height
            LEFT_HEEL_Z=results.pose_landmarks.landmark[29].z

            RIGHT_HEEL_X=results.pose_landmarks.landmark[30].x*image_width
            RIGHT_HEEL_Y=results.pose_landmarks.landmark[30].y*image_height
            RIGHT_HEEL_Z=results.pose_landmarks.landmark[30].z

            LEFT_FOOT_INDEX_X=results.pose_landmarks.landmark[31].x*image_width
            LEFT_FOOT_INDEX_Y=results.pose_landmarks.landmark[31].y*image_height
            LEFT_FOOT_INDEX_Z=results.pose_landmarks.landmark[31].z

            RIGHT_FOOT_INDEX_X=results.pose_landmarks.landmark[32].x*image_width
            RIGHT_FOOT_INDEX_Y=results.pose_landmarks.landmark[32].y*image_height
            RIGHT_FOOT_INDEX_Z=results.pose_landmarks.landmark[32].z


                    # Draw the Skeleton
            mp_drawing.draw_landmarks(annotated_image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

            return (LEFT_EYE_INNER_X, LEFT_EYE_INNER_Y, LEFT_EYE_INNER_Z,
                            LEFT_EYE_X, LEFT_EYE_Y, LEFT_EYE_Z,
                            LEFT_EYE_OUTER_X, LEFT_EYE_OUTER_Y, LEFT_EYE_OUTER_Z,
                            RIGHT_EYE_INNER_X, RIGHT_EYE_INNER_Y, RIGHT_EYE_INNER_Z,
                            RIGHT_EYE_X, RIGHT_EYE_Y, RIGHT_EYE_Z,
                            RIGHT_EYE_OUTER_X, RIGHT_EYE_OUTER_Y, RIGHT_EYE_OUTER_Z,
                            LEFT_EAR_X, LEFT_EAR_Y, LEFT_EAR_Z,
                            RIGHT_EAR_X, RIGHT_EAR_Y, RIGHT_EAR_Z,
                            MOUTH_LEFT_X, MOUTH_LEFT_Y, MOUTH_LEFT_Z,
                            MOUTH_RIGHT_X, MOUTH_RIGHT_Y, MOUTH_RIGHT_Z,
                            LeftShoulder_X, LeftShoulder_Y, LeftShoulder_Z,
                            RIGHT_SHOULDER_X, RIGHT_SHOULDER_Y, RIGHT_SHOULDER_Z,
                            LEFT_ELBOW_X, LEFT_ELBOW_Y, LEFT_ELBOW_Z,
                            RIGHT_ELBOW_X, RIGHT_ELBOW_Y, RIGHT_ELBOW_Z,
                            LEFT_WRIST_X, LEFT_WRIST_Y, LEFT_WRIST_Z,
                            RIGHT_WRIST_X, RIGHT_WRIST_Y, RIGHT_WRIST_Z,
                            LEFT_PINKY_X, LEFT_PINKY_Y, LEFT_PINKY_Z,
                            RIGHT_PINKY_X, RIGHT_PINKY_Y, RIGHT_PINKY_Z,
                            LEFT_INDEX_X, LEFT_INDEX_Y, LEFT_INDEX_Z,
                            RIGHT_INDEX_X, RIGHT_INDEX_Y, RIGHT_INDEX_Z,
                            LEFT_THUMB_X, LEFT_THUMB_Y, LEFT_THUMB_Z,
                            RIGHT_THUMB_X, RIGHT_THUMB_Y, RIGHT_THUMB_Z,
                            LEFT_HIP_X, LEFT_HIP_Y, LEFT_HIP_Z,
                            RIGHT_HIP_X, RIGHT_HIP_Y, RIGHT_HIP_Z,
                            LEFT_KNEE_X, LEFT_KNEE_Y, LEFT_KNEE_Z,
                            RIGHT_KNEE_X, RIGHT_KNEE_Y, RIGHT_KNEE_Z,
                            LEFT_ANKLE_X, LEFT_ANKLE_Y, LEFT_ANKLE_Z,
                            RIGHT_ANKLE_X, RIGHT_ANKLE_Y, RIGHT_ANKLE_Z,
                            LEFT_HEEL_X, LEFT_HEEL_Y, LEFT_HEEL_Z,
                            RIGHT_HEEL_X, RIGHT_HEEL_Y, RIGHT_HEEL_Z,
                            LEFT_FOOT_INDEX_X, LEFT_FOOT_INDEX_Y, LEFT_FOOT_INDEX_Z,
                            RIGHT_FOOT_INDEX_X, RIGHT_FOOT_INDEX_Y, RIGHT_FOOT_INDEX_Z,
                        annotated_image)

# %% [markdown]
# # Add landmarks from Image to CSV file

# %%
#Function to create CSV file or add dataset to the existed CSV file
def toCSV(filecsv, class_type,
          LEFT_EYE_INNER_X, LEFT_EYE_INNER_Y, LEFT_EYE_INNER_Z,
                        LEFT_EYE_X, LEFT_EYE_Y, LEFT_EYE_Z,
                        LEFT_EYE_OUTER_X, LEFT_EYE_OUTER_Y, LEFT_EYE_OUTER_Z,
                        RIGHT_EYE_INNER_X, RIGHT_EYE_INNER_Y, RIGHT_EYE_INNER_Z,
                        RIGHT_EYE_X, RIGHT_EYE_Y, RIGHT_EYE_Z,
                        RIGHT_EYE_OUTER_X, RIGHT_EYE_OUTER_Y, RIGHT_EYE_OUTER_Z,
                        LEFT_EAR_X, LEFT_EAR_Y, LEFT_EAR_Z,
                        RIGHT_EAR_X, RIGHT_EAR_Y, RIGHT_EAR_Z,
                        MOUTH_LEFT_X, MOUTH_LEFT_Y, MOUTH_LEFT_Z,
                        MOUTH_RIGHT_X, MOUTH_RIGHT_Y, MOUTH_RIGHT_Z,
                        LeftShoulder_X, LeftShoulder_Y, LeftShoulder_Z,
                        RIGHT_SHOULDER_X, RIGHT_SHOULDER_Y, RIGHT_SHOULDER_Z,
                        LEFT_ELBOW_X, LEFT_ELBOW_Y, LEFT_ELBOW_Z,
                        RIGHT_ELBOW_X, RIGHT_ELBOW_Y, RIGHT_ELBOW_Z,
                        LEFT_WRIST_X, LEFT_WRIST_Y, LEFT_WRIST_Z,
                        RIGHT_WRIST_X, RIGHT_WRIST_Y, RIGHT_WRIST_Z,
                        LEFT_PINKY_X, LEFT_PINKY_Y, LEFT_PINKY_Z,
                        RIGHT_PINKY_X, RIGHT_PINKY_Y, RIGHT_PINKY_Z,
                        LEFT_INDEX_X, LEFT_INDEX_Y, LEFT_INDEX_Z,
                        RIGHT_INDEX_X, RIGHT_INDEX_Y, RIGHT_INDEX_Z,
                        LEFT_THUMB_X, LEFT_THUMB_Y, LEFT_THUMB_Z,
                        RIGHT_THUMB_X, RIGHT_THUMB_Y, RIGHT_THUMB_Z,
                        LEFT_HIP_X, LEFT_HIP_Y, LEFT_HIP_Z,
                        RIGHT_HIP_X, RIGHT_HIP_Y, RIGHT_HIP_Z,
                        LEFT_KNEE_X, LEFT_KNEE_Y, LEFT_KNEE_Z,
                        RIGHT_KNEE_X, RIGHT_KNEE_Y, RIGHT_KNEE_Z,
                        LEFT_ANKLE_X, LEFT_ANKLE_Y, LEFT_ANKLE_Z,
                        RIGHT_ANKLE_X, RIGHT_ANKLE_Y, RIGHT_ANKLE_Z,
                        LEFT_HEEL_X, LEFT_HEEL_Y, LEFT_HEEL_Z,
                        RIGHT_HEEL_X, RIGHT_HEEL_Y, RIGHT_HEEL_Z,
                        LEFT_FOOT_INDEX_X, LEFT_FOOT_INDEX_Y, LEFT_FOOT_INDEX_Z,
                        RIGHT_FOOT_INDEX_X, RIGHT_FOOT_INDEX_Y, RIGHT_FOOT_INDEX_Z):
    if os.path.isfile(filecsv):
        #print ("File exist thus shall write append to the file")
        with open(filecsv, 'a+', newline='') as file:
            # Create a writer object from csv module
            writer = csv.writer(file)
            writer.writerow([class_type,
                             LEFT_EYE_INNER_X, LEFT_EYE_INNER_Y, LEFT_EYE_INNER_Z,
                        LEFT_EYE_X, LEFT_EYE_Y, LEFT_EYE_Z,
                        LEFT_EYE_OUTER_X, LEFT_EYE_OUTER_Y, LEFT_EYE_OUTER_Z,
                        RIGHT_EYE_INNER_X, RIGHT_EYE_INNER_Y, RIGHT_EYE_INNER_Z,
                        RIGHT_EYE_X, RIGHT_EYE_Y, RIGHT_EYE_Z,
                        RIGHT_EYE_OUTER_X, RIGHT_EYE_OUTER_Y, RIGHT_EYE_OUTER_Z,
                        LEFT_EAR_X, LEFT_EAR_Y, LEFT_EAR_Z,
                        RIGHT_EAR_X, RIGHT_EAR_Y, RIGHT_EAR_Z,
                        MOUTH_LEFT_X, MOUTH_LEFT_Y, MOUTH_LEFT_Z,
                        MOUTH_RIGHT_X, MOUTH_RIGHT_Y, MOUTH_RIGHT_Z,
                        LeftShoulder_X, LeftShoulder_Y, LeftShoulder_Z,
                        RIGHT_SHOULDER_X, RIGHT_SHOULDER_Y, RIGHT_SHOULDER_Z,
                        LEFT_ELBOW_X, LEFT_ELBOW_Y, LEFT_ELBOW_Z,
                        RIGHT_ELBOW_X, RIGHT_ELBOW_Y, RIGHT_ELBOW_Z,
                        LEFT_WRIST_X, LEFT_WRIST_Y, LEFT_WRIST_Z,
                        RIGHT_WRIST_X, RIGHT_WRIST_Y, RIGHT_WRIST_Z,
                        LEFT_PINKY_X, LEFT_PINKY_Y, LEFT_PINKY_Z,
                        RIGHT_PINKY_X, RIGHT_PINKY_Y, RIGHT_PINKY_Z,
                        LEFT_INDEX_X, LEFT_INDEX_Y, LEFT_INDEX_Z,
                        RIGHT_INDEX_X, RIGHT_INDEX_Y, RIGHT_INDEX_Z,
                        LEFT_THUMB_X, LEFT_THUMB_Y, LEFT_THUMB_Z,
                        RIGHT_THUMB_X, RIGHT_THUMB_Y, RIGHT_THUMB_Z,
                        LEFT_HIP_X, LEFT_HIP_Y, LEFT_HIP_Z,
                        RIGHT_HIP_X, RIGHT_HIP_Y, RIGHT_HIP_Z,
                        LEFT_KNEE_X, LEFT_KNEE_Y, LEFT_KNEE_Z,
                        RIGHT_KNEE_X, RIGHT_KNEE_Y, RIGHT_KNEE_Z,
                        LEFT_ANKLE_X, LEFT_ANKLE_Y, LEFT_ANKLE_Z,
                        RIGHT_ANKLE_X, RIGHT_ANKLE_Y, RIGHT_ANKLE_Z,
                        LEFT_HEEL_X, LEFT_HEEL_Y, LEFT_HEEL_Z,
                        RIGHT_HEEL_X, RIGHT_HEEL_Y, RIGHT_HEEL_Z,
                        LEFT_FOOT_INDEX_X, LEFT_FOOT_INDEX_Y, LEFT_FOOT_INDEX_Z,
                        RIGHT_FOOT_INDEX_X, RIGHT_FOOT_INDEX_Y, RIGHT_FOOT_INDEX_Z])
    else:
        #print ("File not exist thus shall create new file as", filecsv)
        with open(filecsv, 'w', newline='') as file:
            # Create a writer object from csv module
            writer = csv.writer(file)
            writer.writerow(["class_type",
                             "LEFT_EYE_INNER_X", "LEFT_EYE_INNER_Y", "LEFT_EYE_INNER_Z",
                        "LEFT_EYE_X", "LEFT_EYE_Y", "LEFT_EYE_Z",
                        "LEFT_EYE_OUTER_X", "LEFT_EYE_OUTER_Y", "LEFT_EYE_OUTER_Z",
                        "RIGHT_EYE_INNER_X", "RIGHT_EYE_INNER_Y", "RIGHT_EYE_INNER_Z",
                        "RIGHT_EYE_X", "RIGHT_EYE_Y", "RIGHT_EYE_Z",
                        "RIGHT_EYE_OUTER_X", "RIGHT_EYE_OUTER_Y", "RIGHT_EYE_OUTER_Z",
                        "LEFT_EAR_X", "LEFT_EAR_Y", "LEFT_EAR_Z",
                        "RIGHT_EAR_X", "RIGHT_EAR_Y", "RIGHT_EAR_Z",
                        "MOUTH_LEFT_X", "MOUTH_LEFT_Y", "MOUTH_LEFT_Z",
                        "MOUTH_RIGHT_X", "MOUTH_RIGHT_Y", "MOUTH_RIGHT_Z",
                        "LeftShoulder_X", "LeftShoulder_Y", "LeftShoulder_Z",
                        "RIGHT_SHOULDER_X", "RIGHT_SHOULDER_Y", "RIGHT_SHOULDER_Z",
                        "LEFT_ELBOW_X", "LEFT_ELBOW_Y", "LEFT_ELBOW_Z",
                        "RIGHT_ELBOW_X", "RIGHT_ELBOW_Y", "RIGHT_ELBOW_Z",
                        "LEFT_WRIST_X", "LEFT_WRIST_Y", "LEFT_WRIST_Z",
                        "RIGHT_WRIST_X", "RIGHT_WRIST_Y", "RIGHT_WRIST_Z",
                        "LEFT_PINKY_X", "LEFT_PINKY_Y", "LEFT_PINKY_Z",
                        "RIGHT_PINKY_X", "RIGHT_PINKY_Y", "RIGHT_PINKY_Z",
                        "LEFT_INDEX_X", "LEFT_INDEX_Y", "LEFT_INDEX_Z",
                        "RIGHT_INDEX_X", "RIGHT_INDEX_Y", "RIGHT_INDEX_Z",
                        "LEFT_THUMB_X", "LEFT_THUMB_Y", "LEFT_THUMB_Z",
                        "RIGHT_THUMB_X", "RIGHT_THUMB_Y", "RIGHT_THUMB_Z",
                        "LEFT_HIP_X", "LEFT_HIP_Y", "LEFT_HIP_Z",
                        "RIGHT_HIP_X", "RIGHT_HIP_Y", "RIGHT_HIP_Z",
                        "LEFT_KNEE_X", "LEFT_KNEE_Y", "LEFT_KNEE_Z",
                        "RIGHT_KNEE_X", "RIGHT_KNEE_Y", "RIGHT_KNEE_Z",
                        "LEFT_ANKLE_X", "LEFT_ANKLE_Y", "LEFT_ANKLE_Z",
                        "RIGHT_ANKLE_X", "RIGHT_ANKLE_Y", "RIGHT_ANKLE_Z",
                        "LEFT_HEEL_X", "LEFT_HEEL_Y", "LEFT_HEEL_Z",
                        "RIGHT_HEEL_X", "RIGHT_HEEL_Y", "RIGHT_HEEL_Z",
                        "LEFT_FOOT_INDEX_X", "LEFT_FOOT_INDEX_Y", "LEFT_FOOT_INDEX_Z",
                        "RIGHT_FOOT_INDEX_X", "RIGHT_FOOT_INDEX_Y", "RIGHT_FOOT_INDEX_Z"])
            writer.writerow([class_type,
                             LEFT_EYE_INNER_X, LEFT_EYE_INNER_Y, LEFT_EYE_INNER_Z,
                        LEFT_EYE_X, LEFT_EYE_Y, LEFT_EYE_Z,
                        LEFT_EYE_OUTER_X, LEFT_EYE_OUTER_Y, LEFT_EYE_OUTER_Z,
                        RIGHT_EYE_INNER_X, RIGHT_EYE_INNER_Y, RIGHT_EYE_INNER_Z,
                        RIGHT_EYE_X, RIGHT_EYE_Y, RIGHT_EYE_Z,
                        RIGHT_EYE_OUTER_X, RIGHT_EYE_OUTER_Y, RIGHT_EYE_OUTER_Z,
                        LEFT_EAR_X, LEFT_EAR_Y, LEFT_EAR_Z,
                        RIGHT_EAR_X, RIGHT_EAR_Y, RIGHT_EAR_Z,
                        MOUTH_LEFT_X, MOUTH_LEFT_Y, MOUTH_LEFT_Z,
                        MOUTH_RIGHT_X, MOUTH_RIGHT_Y, MOUTH_RIGHT_Z,
                        LeftShoulder_X, LeftShoulder_Y, LeftShoulder_Z,
                        RIGHT_SHOULDER_X, RIGHT_SHOULDER_Y, RIGHT_SHOULDER_Z,
                        LEFT_ELBOW_X, LEFT_ELBOW_Y, LEFT_ELBOW_Z,
                        RIGHT_ELBOW_X, RIGHT_ELBOW_Y, RIGHT_ELBOW_Z,
                        LEFT_WRIST_X, LEFT_WRIST_Y, LEFT_WRIST_Z,
                        RIGHT_WRIST_X, RIGHT_WRIST_Y, RIGHT_WRIST_Z,
                        LEFT_PINKY_X, LEFT_PINKY_Y, LEFT_PINKY_Z,
                        RIGHT_PINKY_X, RIGHT_PINKY_Y, RIGHT_PINKY_Z,
                        LEFT_INDEX_X, LEFT_INDEX_Y, LEFT_INDEX_Z,
                        RIGHT_INDEX_X, RIGHT_INDEX_Y, RIGHT_INDEX_Z,
                        LEFT_THUMB_X, LEFT_THUMB_Y, LEFT_THUMB_Z,
                        RIGHT_THUMB_X, RIGHT_THUMB_Y, RIGHT_THUMB_Z,
                        LEFT_HIP_X, LEFT_HIP_Y, LEFT_HIP_Z,
                        RIGHT_HIP_X, RIGHT_HIP_Y, RIGHT_HIP_Z,
                        LEFT_KNEE_X, LEFT_KNEE_Y, LEFT_KNEE_Z,
                             
                        RIGHT_KNEE_X, RIGHT_KNEE_Y, RIGHT_KNEE_Z,
                        LEFT_ANKLE_X, LEFT_ANKLE_Y, LEFT_ANKLE_Z,
                        RIGHT_ANKLE_X, RIGHT_ANKLE_Y, RIGHT_ANKLE_Z,
                        LEFT_HEEL_X, LEFT_HEEL_Y, LEFT_HEEL_Z,
                        RIGHT_HEEL_X, RIGHT_HEEL_Y, RIGHT_HEEL_Z,
                        LEFT_FOOT_INDEX_X, LEFT_FOOT_INDEX_Y, LEFT_FOOT_INDEX_Z,
                        RIGHT_FOOT_INDEX_X, RIGHT_FOOT_INDEX_Y, RIGHT_FOOT_INDEX_Z])

# %% [markdown]
# # Feature Extraction From Image For Training

# %%
# Extract Feature for Training
paths = r"C:\Users\faisal\Pictures\MyDataSet\TRAIN"
csv_path = "tensor_yoga_pose_train.csv"

if os.path.exists(csv_path):
    print("CSV File does exist, going delete before start extraction and replace it with new")
    os.remove(csv_path)
else:
    print("The CSV file does not exist", csv_path, ",Going Create after Extraction")
    
for dirlist in os.listdir(paths):
    for root, directories, filenames in os.walk(os.path.join(paths, dirlist)):
        print("Inside Folder", dirlist, "Consist :", len(filenames), "Imageset")
        for filename in filenames:
            if filename.endswith(".jpg") or filename.endswith(".JPG") or filename.endswith(".png"):
                #print(os.path.join(root, filename), True)
                (LEFT_EYE_INNER_X, LEFT_EYE_INNER_Y, LEFT_EYE_INNER_Z,
                 LEFT_EYE_X, LEFT_EYE_Y, LEFT_EYE_Z,
                 LEFT_EYE_OUTER_X, LEFT_EYE_OUTER_Y, LEFT_EYE_OUTER_Z,
                 RIGHT_EYE_INNER_X, RIGHT_EYE_INNER_Y, RIGHT_EYE_INNER_Z,
                 RIGHT_EYE_X, RIGHT_EYE_Y, RIGHT_EYE_Z,
                 RIGHT_EYE_OUTER_X, RIGHT_EYE_OUTER_Y, RIGHT_EYE_OUTER_Z,
                 LEFT_EAR_X, LEFT_EAR_Y, LEFT_EAR_Z,
                 RIGHT_EAR_X, RIGHT_EAR_Y, RIGHT_EAR_Z,
                 MOUTH_LEFT_X, MOUTH_LEFT_Y, MOUTH_LEFT_Z,
                 MOUTH_RIGHT_X, MOUTH_RIGHT_Y, MOUTH_RIGHT_Z,
                 LeftShoulder_X, LeftShoulder_Y, LeftShoulder_Z,
                 RIGHT_SHOULDER_X, RIGHT_SHOULDER_Y, RIGHT_SHOULDER_Z,
                 LEFT_ELBOW_X, LEFT_ELBOW_Y, LEFT_ELBOW_Z,
                 RIGHT_ELBOW_X, RIGHT_ELBOW_Y, RIGHT_ELBOW_Z,
                 LEFT_WRIST_X, LEFT_WRIST_Y, LEFT_WRIST_Z,
                 RIGHT_WRIST_X, RIGHT_WRIST_Y, RIGHT_WRIST_Z,
                 LEFT_PINKY_X, LEFT_PINKY_Y, LEFT_PINKY_Z,
                 RIGHT_PINKY_X, RIGHT_PINKY_Y, RIGHT_PINKY_Z,
                 LEFT_INDEX_X, LEFT_INDEX_Y, LEFT_INDEX_Z,
                 RIGHT_INDEX_X, RIGHT_INDEX_Y, RIGHT_INDEX_Z,
                 LEFT_THUMB_X, LEFT_THUMB_Y, LEFT_THUMB_Z,
                 RIGHT_THUMB_X, RIGHT_THUMB_Y, RIGHT_THUMB_Z,
                 LEFT_HIP_X, LEFT_HIP_Y, LEFT_HIP_Z,
                 RIGHT_HIP_X, RIGHT_HIP_Y, RIGHT_HIP_Z,
                 LEFT_KNEE_X, LEFT_KNEE_Y, LEFT_KNEE_Z,
                 RIGHT_KNEE_X, RIGHT_KNEE_Y, RIGHT_KNEE_Z,
                 LEFT_ANKLE_X, LEFT_ANKLE_Y, LEFT_ANKLE_Z,
                 RIGHT_ANKLE_X, RIGHT_ANKLE_Y, RIGHT_ANKLE_Z,
                 LEFT_HEEL_X, LEFT_HEEL_Y, LEFT_HEEL_Z,
                 RIGHT_HEEL_X, RIGHT_HEEL_Y, RIGHT_HEEL_Z,
                 LEFT_FOOT_INDEX_X, LEFT_FOOT_INDEX_Y, LEFT_FOOT_INDEX_Z,
                 RIGHT_FOOT_INDEX_X, RIGHT_FOOT_INDEX_Y, RIGHT_FOOT_INDEX_Z,
                 annotated_image) = extract_feature(os.path.join(root, filename))
                
                if ((not LEFT_EYE_INNER_X == 0) and (not LEFT_EYE_INNER_Y == 0)):
                    toCSV(csv_path, dirlist, 
                        LEFT_EYE_INNER_X, LEFT_EYE_INNER_Y, LEFT_EYE_INNER_Z,
                        LEFT_EYE_X, LEFT_EYE_Y, LEFT_EYE_Z,
                        LEFT_EYE_OUTER_X, LEFT_EYE_OUTER_Y, LEFT_EYE_OUTER_Z,
                        RIGHT_EYE_INNER_X, RIGHT_EYE_INNER_Y, RIGHT_EYE_INNER_Z,
                        RIGHT_EYE_X, RIGHT_EYE_Y, RIGHT_EYE_Z,
                        RIGHT_EYE_OUTER_X, RIGHT_EYE_OUTER_Y, RIGHT_EYE_OUTER_Z,
                        LEFT_EAR_X, LEFT_EAR_Y, LEFT_EAR_Z,
                        RIGHT_EAR_X, RIGHT_EAR_Y, RIGHT_EAR_Z,
                        MOUTH_LEFT_X, MOUTH_LEFT_Y, MOUTH_LEFT_Z,
                        MOUTH_RIGHT_X, MOUTH_RIGHT_Y, MOUTH_RIGHT_Z,
                        LeftShoulder_X, LeftShoulder_Y, LeftShoulder_Z,
                        RIGHT_SHOULDER_X, RIGHT_SHOULDER_Y, RIGHT_SHOULDER_Z,
                        LEFT_ELBOW_X, LEFT_ELBOW_Y, LEFT_ELBOW_Z,
                        RIGHT_ELBOW_X, RIGHT_ELBOW_Y, RIGHT_ELBOW_Z,
                        LEFT_WRIST_X, LEFT_WRIST_Y, LEFT_WRIST_Z,
                        RIGHT_WRIST_X, RIGHT_WRIST_Y, RIGHT_WRIST_Z,
                        LEFT_PINKY_X, LEFT_PINKY_Y, LEFT_PINKY_Z,
                        RIGHT_PINKY_X, RIGHT_PINKY_Y, RIGHT_PINKY_Z,
                        LEFT_INDEX_X, LEFT_INDEX_Y, LEFT_INDEX_Z,
                        RIGHT_INDEX_X, RIGHT_INDEX_Y, RIGHT_INDEX_Z,
                        LEFT_THUMB_X, LEFT_THUMB_Y, LEFT_THUMB_Z,
                        RIGHT_THUMB_X, RIGHT_THUMB_Y, RIGHT_THUMB_Z,
                        LEFT_HIP_X, LEFT_HIP_Y, LEFT_HIP_Z,
                        RIGHT_HIP_X, RIGHT_HIP_Y, RIGHT_HIP_Z,
                        LEFT_KNEE_X, LEFT_KNEE_Y, LEFT_KNEE_Z,
                             
                        RIGHT_KNEE_X, RIGHT_KNEE_Y, RIGHT_KNEE_Z,
                        LEFT_ANKLE_X, LEFT_ANKLE_Y, LEFT_ANKLE_Z,
                        RIGHT_ANKLE_X, RIGHT_ANKLE_Y, RIGHT_ANKLE_Z,
                        LEFT_HEEL_X, LEFT_HEEL_Y, LEFT_HEEL_Z,
                        RIGHT_HEEL_X, RIGHT_HEEL_Y, RIGHT_HEEL_Z,
                        LEFT_FOOT_INDEX_X, LEFT_FOOT_INDEX_Y, LEFT_FOOT_INDEX_Z,
                        RIGHT_FOOT_INDEX_X, RIGHT_FOOT_INDEX_Y, RIGHT_FOOT_INDEX_Z)
                
                else :
                    print(os.path.join(root, filename), "Pose does not have landmarks")

print("===================Feature Extraction for TRAINING is Completed===================")
# Out:
# The CSV file does not exist tensor_yoga_pose_train.csv ,Going Create after Extraction
# Inside Folder Downward-Facing Dog Correct Consist : 223 Imageset
# C:\Users\faisal\Pictures\MyDataSet\TRAIN\Downward-Facing Dog Correct\00000139.jpg Pose does not have landmarks
# C:\Users\faisal\Pictures\MyDataSet\TRAIN\Downward-Facing Dog Correct\00000147.jpg Pose does not have landmarks
# C:\Users\faisal\Pictures\MyDataSet\TRAIN\Downward-Facing Dog Correct\00000153.jpg Pose does not have landmarks
# C:\Users\faisal\Pictures\MyDataSet\TRAIN\Downward-Facing Dog Correct\00000163.jpg Pose does not have landmarks
# C:\Users\faisal\Pictures\MyDataSet\TRAIN\Downward-Facing Dog Correct\00000168.jpg Pose does not have landmarks
# C:\Users\faisal\Pictures\MyDataSet\TRAIN\Downward-Facing Dog Correct\00000173.jpg Pose does not have landmarks
# C:\Users\faisal\Pictures\MyDataSet\TRAIN\Downward-Facing Dog Correct\00000175.jpg Pose does not have landmarks
# ...

# %% [markdown]
# # Feature Extraction From Image For Validation

# %%
# Extract Feature for Validation
paths = r"C:\Users\faisal\Pictures\MyDataSet\TEST"
csv_path = "tensor_yoga_pose_test.csv"

if os.path.exists(csv_path):
    print("CSV File does exist, going delete before start extraction and replace it with new")
    os.remove(csv_path)
else:
    print("The CSV file does not exist", csv_path, ",Going Create after Extraction")
    
for dirlist in os.listdir(paths):
    for root, directories, filenames in os.walk(os.path.join(paths, dirlist)):
        print("Inside Folder", dirlist, "Consist :", len(filenames), "Imageset")
        for filename in filenames:
            if filename.endswith(".jpg") or filename.endswith(".JPG") or filename.endswith(".png"):
                #print(os.path.join(root, filename), True)
                (LEFT_EYE_INNER_X, LEFT_EYE_INNER_Y, LEFT_EYE_INNER_Z,
                 LEFT_EYE_X, LEFT_EYE_Y, LEFT_EYE_Z,
                 LEFT_EYE_OUTER_X, LEFT_EYE_OUTER_Y, LEFT_EYE_OUTER_Z,
                 RIGHT_EYE_INNER_X, RIGHT_EYE_INNER_Y, RIGHT_EYE_INNER_Z,
                 RIGHT_EYE_X, RIGHT_EYE_Y, RIGHT_EYE_Z,
                 RIGHT_EYE_OUTER_X, RIGHT_EYE_OUTER_Y, RIGHT_EYE_OUTER_Z,
                 LEFT_EAR_X, LEFT_EAR_Y, LEFT_EAR_Z,
                 RIGHT_EAR_X, RIGHT_EAR_Y, RIGHT_EAR_Z,
                 MOUTH_LEFT_X, MOUTH_LEFT_Y, MOUTH_LEFT_Z,
                 MOUTH_RIGHT_X, MOUTH_RIGHT_Y, MOUTH_RIGHT_Z,
                 LeftShoulder_X, LeftShoulder_Y, LeftShoulder_Z,
                 RIGHT_SHOULDER_X, RIGHT_SHOULDER_Y, RIGHT_SHOULDER_Z,
                 LEFT_ELBOW_X, LEFT_ELBOW_Y, LEFT_ELBOW_Z,
                 RIGHT_ELBOW_X, RIGHT_ELBOW_Y, RIGHT_ELBOW_Z,
                 LEFT_WRIST_X, LEFT_WRIST_Y, LEFT_WRIST_Z,
                 RIGHT_WRIST_X, RIGHT_WRIST_Y, RIGHT_WRIST_Z,
                 LEFT_PINKY_X, LEFT_PINKY_Y, LEFT_PINKY_Z,
                 RIGHT_PINKY_X, RIGHT_PINKY_Y, RIGHT_PINKY_Z,
                 LEFT_INDEX_X, LEFT_INDEX_Y, LEFT_INDEX_Z,
                 RIGHT_INDEX_X, RIGHT_INDEX_Y, RIGHT_INDEX_Z,
                 LEFT_THUMB_X, LEFT_THUMB_Y, LEFT_THUMB_Z,
                 RIGHT_THUMB_X, RIGHT_THUMB_Y, RIGHT_THUMB_Z,
                 LEFT_HIP_X, LEFT_HIP_Y, LEFT_HIP_Z,
                 RIGHT_HIP_X, RIGHT_HIP_Y, RIGHT_HIP_Z,
                 LEFT_KNEE_X, LEFT_KNEE_Y, LEFT_KNEE_Z,
                 RIGHT_KNEE_X, RIGHT_KNEE_Y, RIGHT_KNEE_Z,
                 LEFT_ANKLE_X, LEFT_ANKLE_Y, LEFT_ANKLE_Z,
                 RIGHT_ANKLE_X, RIGHT_ANKLE_Y, RIGHT_ANKLE_Z,
                 LEFT_HEEL_X, LEFT_HEEL_Y, LEFT_HEEL_Z,
                 RIGHT_HEEL_X, RIGHT_HEEL_Y, RIGHT_HEEL_Z,
                 LEFT_FOOT_INDEX_X, LEFT_FOOT_INDEX_Y, LEFT_FOOT_INDEX_Z,
                 RIGHT_FOOT_INDEX_X, RIGHT_FOOT_INDEX_Y, RIGHT_FOOT_INDEX_Z,
                 annotated_image) = extract_feature(os.path.join(root, filename))
            
                if ((not LEFT_EYE_INNER_X == 0) and (not LEFT_EYE_INNER_Y == 0)):
                    toCSV(csv_path, dirlist, 
                          LEFT_EYE_INNER_X, LEFT_EYE_INNER_Y, LEFT_EYE_INNER_Z,
                 LEFT_EYE_X, LEFT_EYE_Y, LEFT_EYE_Z,
                 LEFT_EYE_OUTER_X, LEFT_EYE_OUTER_Y, LEFT_EYE_OUTER_Z,
                 RIGHT_EYE_INNER_X, RIGHT_EYE_INNER_Y, RIGHT_EYE_INNER_Z,
                 RIGHT_EYE_X, RIGHT_EYE_Y, RIGHT_EYE_Z,
                 RIGHT_EYE_OUTER_X, RIGHT_EYE_OUTER_Y, RIGHT_EYE_OUTER_Z,
                 LEFT_EAR_X, LEFT_EAR_Y, LEFT_EAR_Z,
                 RIGHT_EAR_X, RIGHT_EAR_Y, RIGHT_EAR_Z,
                 MOUTH_LEFT_X, MOUTH_LEFT_Y, MOUTH_LEFT_Z,
                 MOUTH_RIGHT_X, MOUTH_RIGHT_Y, MOUTH_RIGHT_Z,
                 LeftShoulder_X, LeftShoulder_Y, LeftShoulder_Z,
                 RIGHT_SHOULDER_X, RIGHT_SHOULDER_Y, RIGHT_SHOULDER_Z,
                 LEFT_ELBOW_X, LEFT_ELBOW_Y, LEFT_ELBOW_Z,
                 RIGHT_ELBOW_X, RIGHT_ELBOW_Y, RIGHT_ELBOW_Z,
                 LEFT_WRIST_X, LEFT_WRIST_Y, LEFT_WRIST_Z,
                 RIGHT_WRIST_X, RIGHT_WRIST_Y, RIGHT_WRIST_Z,
                 LEFT_PINKY_X, LEFT_PINKY_Y, LEFT_PINKY_Z,
                 RIGHT_PINKY_X, RIGHT_PINKY_Y, RIGHT_PINKY_Z,
                 LEFT_INDEX_X, LEFT_INDEX_Y, LEFT_INDEX_Z,
                 RIGHT_INDEX_X, RIGHT_INDEX_Y, RIGHT_INDEX_Z,
                 LEFT_THUMB_X, LEFT_THUMB_Y, LEFT_THUMB_Z,
                 RIGHT_THUMB_X, RIGHT_THUMB_Y, RIGHT_THUMB_Z,
                 LEFT_HIP_X, LEFT_HIP_Y, LEFT_HIP_Z,
                 RIGHT_HIP_X, RIGHT_HIP_Y, RIGHT_HIP_Z,
                 LEFT_KNEE_X, LEFT_KNEE_Y, LEFT_KNEE_Z,
                 RIGHT_KNEE_X, RIGHT_KNEE_Y, RIGHT_KNEE_Z,
                 LEFT_ANKLE_X, LEFT_ANKLE_Y, LEFT_ANKLE_Z,
                 RIGHT_ANKLE_X, RIGHT_ANKLE_Y, RIGHT_ANKLE_Z,
                 LEFT_HEEL_X, LEFT_HEEL_Y, LEFT_HEEL_Z,
                 RIGHT_HEEL_X, RIGHT_HEEL_Y, RIGHT_HEEL_Z,
                 LEFT_FOOT_INDEX_X, LEFT_FOOT_INDEX_Y, LEFT_FOOT_INDEX_Z,
                 RIGHT_FOOT_INDEX_X, RIGHT_FOOT_INDEX_Y, RIGHT_FOOT_INDEX_Z)
                
                else :
                    print(os.path.join(root, filename), "Pose does not have landmarks")
                
print("===================Feature Extraction for VALIDATION is Completed===================")
# Out:
# The CSV file does not exist tensor_yoga_pose_test.csv ,Going Create after Extraction
# Inside Folder Downward-Facing Dog Correct Consist : 97 Imageset
# C:\Users\faisal\Pictures\MyDataSet\TEST\Downward-Facing Dog Correct\00000010.png Pose does not have landmarks
# C:\Users\faisal\Pictures\MyDataSet\TEST\Downward-Facing Dog Correct\00000016.jpg Pose does not have landmarks
# C:\Users\faisal\Pictures\MyDataSet\TEST\Downward-Facing Dog Correct\00000025.jpg Pose does not have landmarks
# C:\Users\faisal\Pictures\MyDataSet\TEST\Downward-Facing Dog Correct\00000031.jpg Pose does not have landmarks
# C:\Users\faisal\Pictures\MyDataSet\TEST\Downward-Facing Dog Correct\00000035.jpg Pose does not have landmarks
# C:\Users\faisal\Pictures\MyDataSet\TEST\Downward-Facing Dog Correct\00000041.png Pose does not have landmarks
# C:\Users\faisal\Pictures\MyDataSet\TEST\Downward-Facing Dog Correct\00000042.jpg Pose does not have landmarks
# ...

# %%
# Read CSV file for Training the model using Pandas
df_train = pd.read_csv("tensor_yoga_pose_train.csv", header=0)

# First we must sort the values of the dataset according to the Alphabets
df_train = df_train.sort_values(by=["class_type"])

df_train
# Out:
#                        class_type  LEFT_EYE_INNER_X  LEFT_EYE_INNER_Y  \
# 0     Downward-Facing Dog Correct        359.866817        385.475708
# 117   Downward-Facing Dog Correct        361.857331        271.327491
# 118   Downward-Facing Dog Correct        441.350931        654.664962
# 119   Downward-Facing Dog Correct        778.942037        708.387983
# 120   Downward-Facing Dog Correct        313.854218        153.480842
# ...                           ...               ...               ...
# 1145         Warrior II Incorrect        152.183271         23.878285
# 1146         Warrior II Incorrect        296.991908         39.474551
# 1147         Warrior II Incorrect        187.472892        364.556922
# 1148         Warrior II Incorrect        461.203217         33.786457
# 1150         Warrior II Incorrect        491.481855        321.511362
#
#       LEFT_EYE_INNER_Z  LEFT_EYE_X  LEFT_EYE_Y  LEFT_EYE_Z  LEFT_EYE_OUTER_X  \
# ...

# %%
# Read CSV file for Validation or Testing the Model using Pandas
df_test = pd.read_csv("tensor_yoga_pose_test.csv", header=0)

# First we must sort the values of the dataset according to the Alphabets
df_test = df_test.sort_values(by=["class_type"])

df_test
# Out:
#                       class_type  LEFT_EYE_INNER_X  LEFT_EYE_INNER_Y  \
# 0    Downward-Facing Dog Correct        631.529655        545.920000
# 59   Downward-Facing Dog Correct        105.902490        186.332148
# 58   Downward-Facing Dog Correct        411.994421        508.205773
# 57   Downward-Facing Dog Correct        244.132723        317.416786
# 56   Downward-Facing Dog Correct        761.701120        787.396351
# ..                           ...               ...               ...
# 550         Warrior II Incorrect        152.183271         23.878285
# 551         Warrior II Incorrect        296.991908         39.474551
# 552         Warrior II Incorrect        187.472892        364.556922
# 553         Warrior II Incorrect        461.203217         33.786457
# 555         Warrior II Incorrect        491.481855        321.511362
#
#      LEFT_EYE_INNER_Z  LEFT_EYE_X  LEFT_EYE_Y  LEFT_EYE_Z  LEFT_EYE_OUTER_X  \
# ...

# %%
# Put Categorical using Pandas
df_train["class_type"] = pd.Categorical(df_train["class_type"])
df_train["class_type"] = df_train.class_type.cat.codes

df_test["class_type"] = pd.Categorical(df_test["class_type"])
df_test["class_type"] = df_test.class_type.cat.codes

# %%
df_train.head()
# Out:
#      class_type  LEFT_EYE_INNER_X  LEFT_EYE_INNER_Y  LEFT_EYE_INNER_Z  \
# 0             0        359.866817        385.475708         -0.252977
# 117           0        361.857331        271.327491         -0.041213
# 118           0        441.350931        654.664962         -0.043878
# 119           0        778.942037        708.387983         -0.068046
# 120           0        313.854218        153.480842          0.007631
#
#      LEFT_EYE_X  LEFT_EYE_Y  LEFT_EYE_Z  LEFT_EYE_OUTER_X  LEFT_EYE_OUTER_Y  \
# 0    357.929684  383.394848   -0.253006        355.909137        381.345588
# 117  363.138151  271.499318   -0.041158        364.631385        271.519754
# 118  442.639366  653.606853   -0.043913        444.054147        652.422565
# 119  781.626385  705.846321   -0.068159        784.615564        703.088700
# 120  314.702570  153.252305    0.007507        315.806031        153.016019
#
#      LEFT_EYE_OUTER_Z  ...  LEFT_HEEL_Z  RIGHT_HEEL_X  RIGHT_HEEL_Y  \
# ...

# %%
# Copy Label and Feature for training
y_train = df_train.pop("class_type")
x_train = df_train.copy()

y_test = df_test.pop("class_type")
x_test = df_test.copy()

# Copied Features turn to Array by using NumPy
x_train = np.array(x_train)
x_test = np.array(x_test)

# %%
y_test.shape
# Out:
# (552,)

# %%
dataframe = pd.read_csv("tensor_yoga_pose_train.csv")
df_to_process = dataframe.copy()
classes = df_to_process.pop('class_type').unique()

# %%
# Check Array Shape before transformation
print(x_train.shape)
print(x_test.shape)

 # Since the array shape is 1x1, we must turn it into 1x96x1 so we can feed it into the model
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Check Array Shape after transformation
print(x_train.shape)
print(x_test.shape)
# Out:
# (1151, 96)
# (556, 96)
# (1151, 96, 1)
# (556, 96, 1)

# %%
# Check sample train and test features
#print(x_train[0])
print(x_test[551])
# Out:
# [[152.183]
#  [ 23.878]
#  [ -0.373]
#  [153.97 ]
#  [ 23.997]
#  [ -0.372]
#  [155.73 ]
#  [ 24.128]
#  [ -0.373]
#  [149.55 ]
#  [ 23.465]
#  [ -0.341]
#  [149.362]
#  [ 23.3  ]
#  [ -0.341]
#  [149.175]
#  [ 23.091]
#  [ -0.341]
#  [164.365]
#  [ 27.793]
#  [ -0.321]
#  [155.637]
#  [ 26.15 ]
#  [ -0.168]
#  [149.557]
#  [ 34.893]
#  [ -0.348]
#  [146.294]
#  [ 33.936]
#  [ -0.304]
#  [188.294]
#  [ 60.021]
#  [ -0.248]
#  [132.45 ]
#  [ 52.055]
#  [ -0.095]
#  [237.653]
#  [ 59.217]
#  [ -0.313]
#  [ 88.231]
#  [ 51.931]
#  [ -0.098]
#  [278.171]
#  [ 55.353]
#  [ -0.42 ]
#  [ 46.991]
#  [ 52.308]
#  [ -0.26 ]
#  [290.05 ]
#  [ 55.207]
#  [ -0.439]
#  [ 33.342]
#  [ 51.009]
#  [ -0.285]
#  [293.154]
#  [ 53.306]
#  [ -0.496]
#  [ 32.475]
#  [ 50.412]
#  [ -0.337]
#  [288.709]
#  [ 54.376]
#  [ -0.451]
#  [ 36.459]
#  [ 52.017]
#  [ -0.291]
#  [175.43 ]
#  [138.7  ]
#  [ -0.077]
#  [142.597]
#  [137.937]
#  [  0.076]
#  [226.318]
#  [173.214]
#  [ -0.235]
#  [ 81.443]
# ...

# %%
from keras.utils import to_categorical

# %%
num_classes = 10

# Using the Keras.Utils to put the label categorically 
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# %%
y_test.shape
# Out:
# (556, 10)

# %% [markdown]
# # 1x1 CNN Model

# %%
# One Dimensional Convolutional Neural Network model, Train will be feed to 1 Dimension Convolutional Neural Network
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(filters=32, kernel_size=5, strides=1, padding="causal", activation="relu", input_shape=x_train.shape[1:3]),
    tf.keras.layers.Conv1D(filters=32, kernel_size=5, strides=1, padding="causal", activation="relu"),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.Conv1D(filters=64, kernel_size=5, strides=1, padding="causal", activation="relu"),
    tf.keras.layers.Conv1D(filters=64, kernel_size=5, strides=1, padding="causal", activation="relu"),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.Conv1D(filters=128, kernel_size=5, strides=1, padding="causal", activation="relu"),
    tf.keras.layers.Conv1D(filters=128, kernel_size=5, strides=1, padding="causal", activation="relu"),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.Conv1D(filters=256, kernel_size=5, strides=1, padding="causal", activation="relu"),
    tf.keras.layers.Conv1D(filters=256, kernel_size=5, strides=1, padding="causal", activation="relu"),
    tf.keras.layers.MaxPooling1D(pool_size=2),
    tf.keras.layers.Dropout(rate=0.2),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'), 
    tf.keras.layers.Dense(num_classes, activation='softmax')])

model.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d (Conv1D)             (None, 96, 32)            192
#
#  conv1d_1 (Conv1D)           (None, 96, 32)            5152
#
#  max_pooling1d (MaxPooling1D  (None, 48, 32)           0
#  )
#
#  conv1d_2 (Conv1D)           (None, 48, 64)            10304
#
#  conv1d_3 (Conv1D)           (None, 48, 64)            20544
#
#  max_pooling1d_1 (MaxPooling  (None, 24, 64)           0
#  1D)
#
#  conv1d_4 (Conv1D)           (None, 24, 128)           41088
#
#  conv1d_5 (Conv1D)           (None, 24, 128)           82048
#
#  max_pooling1d_2 (MaxPooling  (None, 12, 128)          0
#  1D)
#
#  conv1d_6 (Conv1D)           (None, 12, 256)           164096
#
#  conv1d_7 (Conv1D)           (None, 12, 256)           327936
#
#  max_pooling1d_3 (MaxPooling  (None, 6, 256)           0
#  1D)
#
# ...

# %% [markdown]
# # Training

# %%
#Train the Model
history =model.fit(x_train, y_train, epochs=100, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Epoch 1/100
# 36/36 [==============================] - 5s 60ms/step - loss: 2.5536 - accuracy: 0.2563 - val_loss: 2.0136 - val_accuracy: 0.3921
# Epoch 2/100
# 36/36 [==============================] - 2s 51ms/step - loss: 1.5362 - accuracy: 0.4926 - val_loss: 1.4021 - val_accuracy: 0.5252
# Epoch 3/100
# 36/36 [==============================] - 2s 51ms/step - loss: 1.3452 - accuracy: 0.5917 - val_loss: 1.1947 - val_accuracy: 0.6097
# Epoch 4/100
# 36/36 [==============================] - 2s 49ms/step - loss: 1.1106 - accuracy: 0.6551 - val_loss: 0.9760 - val_accuracy: 0.7086
# Epoch 5/100
# 36/36 [==============================] - 2s 48ms/step - loss: 0.9947 - accuracy: 0.6907 - val_loss: 1.1551 - val_accuracy: 0.6313
# Epoch 6/100
# 36/36 [==============================] - 2s 48ms/step - loss: 0.9577 - accuracy: 0.7298 - val_loss: 0.7904 - val_accuracy: 0.7374
# Epoch 7/100
# ...

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['TRAIN', 'VAL'], loc='lower right')
plt.show()

# %% [markdown]
# # Evaluating Model

# %%
loss, accuracy = model.evaluate(x_test, y_test)
# Out:
# 18/18 [==============================] - 0s 9ms/step - loss: 0.2586 - accuracy: 0.9514

# %%
#Saving the model into H5 system file
save_model = "YogaTraindedModel.h5"
model.save(save_model)
print("Model Saved into", save_model)
# Out:
# Model Saved into YogaTraindedModel.h5

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import itertools

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  """Plots the confusion matrix."""
  if normalize:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print("Normalized confusion matrix")
  else:
    print('Confusion matrix, without normalization')

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=90)
  plt.yticks(tick_marks, classes)
  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt),
              horizontalalignment="center",
              color="white" if cm[i, j] > thresh else "black")

  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.tight_layout(pad=5)

# Classify pose in the TEST dataset using the trained model
y_pred = model.predict(x_test)

# Convert the prediction result to class name
y_pred_label = [classes[i] for i in np.argmax(y_pred, axis=1)]
y_true_label = [classes[i] for i in np.argmax(y_test, axis=1)]

# Plot the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))
plot_confusion_matrix(cm,
                      classes,
                      title ='Confusion Matrix of Pose Classification Model')

# Print the classification report
print('\nClassification Report:\n', classification_report(y_true_label,
                                                          y_pred_label))
# Out:
# 18/18 [==============================] - 0s 9ms/step
# Confusion matrix, without normalization
#
# Classification Report:
#                                 precision    recall  f1-score   support
#
#   Downward-Facing Dog Correct       0.96      0.90      0.93        82
# Downward-Facing Dog Incorrect       1.00      0.90      0.95        20
#                 Plank Correct       0.92      0.92      0.92       114
#               Plank Incorrect       0.88      0.98      0.93        51
#                Squats Correct       0.95      0.97      0.96        77
#              Squats Incorrect       1.00      1.00      1.00        25
#                  Tree Correct       1.00      0.99      0.99        69
#                Tree Incorrect       1.00      1.00      1.00         5
#            Warrior II Correct       0.96      0.98      0.97       107
#          Warrior II Incorrect       1.00      0.67      0.80         6
#
# ...

# %%
classes = {
    'Downward-Facing Dog Correct': 0,
    'Downward-Facing Dog Incorrect': 1,
    'Plank Correct' :2,
    'Plank Incorrect' :3,
    'Squats Correct' :4,
    'Squats Incorrect' :5,
    'Tree Correct' :6,
    'Tree Incorrect' :7,
    'Warrior II Correct' :8,
    'Warrior II Incorrect' :9,
}

# %%
# Directly from Imageset Dataset Testing
#Load Image and do Feature Extraction
path_to_image ="01.jpg"

(LEFT_EYE_INNER_X, LEFT_EYE_INNER_Y, LEFT_EYE_INNER_Z,
                 LEFT_EYE_X, LEFT_EYE_Y, LEFT_EYE_Z,
                 LEFT_EYE_OUTER_X, LEFT_EYE_OUTER_Y, LEFT_EYE_OUTER_Z,
                 RIGHT_EYE_INNER_X, RIGHT_EYE_INNER_Y, RIGHT_EYE_INNER_Z,
                 RIGHT_EYE_X, RIGHT_EYE_Y, RIGHT_EYE_Z,
                 RIGHT_EYE_OUTER_X, RIGHT_EYE_OUTER_Y, RIGHT_EYE_OUTER_Z,
                 LEFT_EAR_X, LEFT_EAR_Y, LEFT_EAR_Z,
                 RIGHT_EAR_X, RIGHT_EAR_Y, RIGHT_EAR_Z,
                 MOUTH_LEFT_X, MOUTH_LEFT_Y, MOUTH_LEFT_Z,
                 MOUTH_RIGHT_X, MOUTH_RIGHT_Y, MOUTH_RIGHT_Z,
                 LeftShoulder_X, LeftShoulder_Y, LeftShoulder_Z,
                 RIGHT_SHOULDER_X, RIGHT_SHOULDER_Y, RIGHT_SHOULDER_Z,
                 LEFT_ELBOW_X, LEFT_ELBOW_Y, LEFT_ELBOW_Z,
                 RIGHT_ELBOW_X, RIGHT_ELBOW_Y, RIGHT_ELBOW_Z,
                 LEFT_WRIST_X, LEFT_WRIST_Y, LEFT_WRIST_Z,
                 RIGHT_WRIST_X, RIGHT_WRIST_Y, RIGHT_WRIST_Z,
                 LEFT_PINKY_X, LEFT_PINKY_Y, LEFT_PINKY_Z,
                 RIGHT_PINKY_X, RIGHT_PINKY_Y, RIGHT_PINKY_Z,
                 LEFT_INDEX_X, LEFT_INDEX_Y, LEFT_INDEX_Z,
                 RIGHT_INDEX_X, RIGHT_INDEX_Y, RIGHT_INDEX_Z,
                 LEFT_THUMB_X, LEFT_THUMB_Y, LEFT_THUMB_Z,
                 RIGHT_THUMB_X, RIGHT_THUMB_Y, RIGHT_THUMB_Z,
                 LEFT_HIP_X, LEFT_HIP_Y, LEFT_HIP_Z,
                 RIGHT_HIP_X, RIGHT_HIP_Y, RIGHT_HIP_Z,
                 LEFT_KNEE_X, LEFT_KNEE_Y, LEFT_KNEE_Z,
                 RIGHT_KNEE_X, RIGHT_KNEE_Y, RIGHT_KNEE_Z,
                 LEFT_ANKLE_X, LEFT_ANKLE_Y, LEFT_ANKLE_Z,
                 RIGHT_ANKLE_X, RIGHT_ANKLE_Y, RIGHT_ANKLE_Z,
                 LEFT_HEEL_X, LEFT_HEEL_Y, LEFT_HEEL_Z,
                 RIGHT_HEEL_X, RIGHT_HEEL_Y, RIGHT_HEEL_Z,
                 LEFT_FOOT_INDEX_X, LEFT_FOOT_INDEX_Y, LEFT_FOOT_INDEX_Z,
                 RIGHT_FOOT_INDEX_X, RIGHT_FOOT_INDEX_Y, RIGHT_FOOT_INDEX_Z,
 output_IMG) = extract_feature(path_to_image)
input_IMG = np.array([[[LEFT_EYE_INNER_X], [LEFT_EYE_INNER_Y], [LEFT_EYE_INNER_Z],
                     [LEFT_EYE_X], [LEFT_EYE_Y], [LEFT_EYE_Z],
                     [LEFT_EYE_OUTER_X], [LEFT_EYE_OUTER_Y], [LEFT_EYE_OUTER_Z],
                     [RIGHT_EYE_INNER_X], [RIGHT_EYE_INNER_Y], [RIGHT_EYE_INNER_Z],
                     [RIGHT_EYE_X], [RIGHT_EYE_Y], [RIGHT_EYE_Z],
                     [RIGHT_EYE_OUTER_X], [RIGHT_EYE_OUTER_Y], [RIGHT_EYE_OUTER_Z],
                     [LEFT_EAR_X], [LEFT_EAR_Y], [LEFT_EAR_Z],
                     [RIGHT_EAR_X], [RIGHT_EAR_Y], [RIGHT_EAR_Z],
                     [MOUTH_LEFT_X], [MOUTH_LEFT_Y], [MOUTH_LEFT_Z],
                     [MOUTH_RIGHT_X], [MOUTH_RIGHT_Y], [MOUTH_RIGHT_Z],
                     [LeftShoulder_X], [LeftShoulder_Y], [LeftShoulder_Z],
                     [RIGHT_SHOULDER_X], [RIGHT_SHOULDER_Y], [RIGHT_SHOULDER_Z],
                     [LEFT_ELBOW_X], [LEFT_ELBOW_Y], [LEFT_ELBOW_Z],
                     [RIGHT_ELBOW_X], [RIGHT_ELBOW_Y], [RIGHT_ELBOW_Z],
                     [LEFT_WRIST_X], [LEFT_WRIST_Y], [LEFT_WRIST_Z],
                     [RIGHT_WRIST_X], [RIGHT_WRIST_Y], [RIGHT_WRIST_Z],
                     [LEFT_PINKY_X], [LEFT_PINKY_Y], [LEFT_PINKY_Z],
                     [RIGHT_PINKY_X], [RIGHT_PINKY_Y], [RIGHT_PINKY_Z],
                     [LEFT_INDEX_X], [LEFT_INDEX_Y], [LEFT_INDEX_Z],
                     [RIGHT_INDEX_X], [RIGHT_INDEX_Y], [RIGHT_INDEX_Z],
                     [LEFT_THUMB_X], [LEFT_THUMB_Y], [LEFT_THUMB_Z],
                     [LEFT_THUMB_X], [LEFT_THUMB_Y], [LEFT_THUMB_Z],
                       [RIGHT_THUMB_X], [RIGHT_THUMB_Y], [RIGHT_THUMB_Z],
                       [LEFT_HIP_X], [LEFT_HIP_Y], [LEFT_HIP_Z],
                       [RIGHT_HIP_X], [RIGHT_HIP_Y], [RIGHT_HIP_Z],
                       [LEFT_KNEE_X], [LEFT_KNEE_Y], [LEFT_KNEE_Z],
                       [RIGHT_KNEE_X], [RIGHT_KNEE_Y], [RIGHT_KNEE_Z],
                       [RIGHT_ANKLE_X], [RIGHT_ANKLE_Y], [RIGHT_ANKLE_Z],
                       [LEFT_HEEL_X], [LEFT_HEEL_Y], [LEFT_HEEL_Z],
                       [RIGHT_HEEL_X], [RIGHT_HEEL_Y], [RIGHT_HEEL_Z],
                       [LEFT_FOOT_INDEX_X], [LEFT_FOOT_INDEX_Y], [LEFT_FOOT_INDEX_Z],
                       [RIGHT_FOOT_INDEX_X], [RIGHT_FOOT_INDEX_Y], [RIGHT_FOOT_INDEX_X]
                      ]])

#print(wristX, wristY,
#      thumb_CmcX, thumb_CmcY, thumb_McpX, thumb_McpY, thumb_IpX, thumb_IpY, thumb_TipX, thumb_TipY,
#      index_McpX, index_McpY, index_PipX, index_PipY, index_DipX, index_DipY, index_TipX, index_TipY,
#      middle_McpX, middle_McpY, middle_PipX, middle_PipY, middle_DipX, middle_DipY, middle_TipX, middle_TipY,
#      ring_McpX, ring_McpY, ring_PipX, ring_PipY, ring_DipX, ring_DipY, ring_TipX, ring_TipY,
#      pinky_McpX, pinky_McpY, pinky_PipX, pinky_PipY, pinky_DipX, pinky_DipY, pinky_TipX, pinky_TipY)
plt.axis("on")
plt.imshow(cv.cvtColor(output_IMG, cv.COLOR_BGR2RGB))
plt.show()

# %%
#Print the Prediction
predict_x=model.predict(input_IMG)
classes_x=np.argmax(predict_x,axis=1)
print(predict_x)
print(classes_x)
# Out:
# [[0.102 0.    0.    0.002 0.002 0.893 0.    0.    0.    0.   ]]
# [5]

# %%
#Print prediction using defined Classes
classes_x=np.argmax(predict_x)
for pose, values in classes.items():
    if values == classes_x:
        print("Possible pose according to the input : ", pose,values)
# Out:
# Possible pose according to the input :  Squats Incorrect 5

# %% [markdown]
# # Convert trained model to tensorflow lite

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

print('Model size: %dKB' % (len(tflite_model) / 1024))

with open('pose_classifier.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Faisal\AppData\Local\Temp\tmpovdqfyn4\assets
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# Model size: 1446KB

# %%
with open('pose_labels.txt', 'w') as f:
  f.write('\n'.join(classes))

# %%
from tensorflow.keras.utils import to_categorical

# %%
from sklearn.metrics import accuracy_score

# %%
from keras.utils import np_utils

# %%
def evaluate_model(interpreter, X, y_true):
  """Evaluates the given TFLite model and return its accuracy."""
  input_index = interpreter.get_input_details()[0]["index"]
  output_index = interpreter.get_output_details()[0]["index"]

  # Run predictions on all given poses.
  y_pred = []
  for i in range(len(y_true)):
    # Pre-processing: add batch dimension and convert to float32 to match with
    # the model's input data format.
    test_image = X[i: i + 1].astype('float32')
    interpreter.set_tensor(input_index, test_image)

    # Run inference.
    interpreter.invoke()

    # Post-processing: remove batch dimension and find the class with highest
    # probability.
    output = interpreter.tensor(output_index)
    predicted_label = np.argmax(output()[0])
    y_pred.append(predicted_label)

  # Compare prediction results with ground truth labels to calculate accuracy.
  y_pred = keras.utils.np_utils.to_categorical(y_pred)
  return accuracy_score(y_true, y_pred)

# Evaluate the accuracy of the converted TFLite model
classifier_interpreter = tf.lite.Interpreter(model_content=tflite_model)
classifier_interpreter.allocate_tensors()
print('Accuracy of TFLite model: %s' %
      evaluate_model(classifier_interpreter, x_test, y_test))
# Out:
# Accuracy of TFLite model: 0.9940828402366864

# %%
import numpy as np
import tensorflow as tf

# Load the TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_path="pose_classifier.tflite")
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
print(input_details)
#print(output_details)

# Test the model on random input data.
input_shape = input_details[0]['shape']
input_data = np.array(np.random.random_sample(input_shape), dtype=np.float32)
interpreter.set_tensor(input_details[0]['index'], input_data)

interpreter.invoke()

# The function `get_tensor()` returns a copy of the tensor data.
# Use `tensor()` in order to get a pointer to the tensor.
output_data = interpreter.get_tensor(output_details[0]['index'])
print(output_data)
# Out:
# [{'name': 'serving_default_conv1d_input:0', 'index': 0, 'shape': array([ 1, 96,  1]), 'shape_signature': array([-1, 96,  1]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# [[0.002 0.188 0.272 0.506 0.018 0.001 0.001 0.    0.    0.012]]

# %%
import numpy as np
import tensorflow as tf

# Load the TFLite model and allocate tensors.
interpreter = tf.lite.Interpreter(model_path="classifier.tflite")
interpreter.allocate_tensors()

# Get input and output tensors.
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
#print(output_details)
print(input_details)

# Test the model on random input data.
input_shape = input_details[0]['shape']
input_data = np.array(np.random.random_sample(input_shape), dtype=np.float32)
interpreter.set_tensor(input_details[0]['index'], input_data)

interpreter.invoke()

# The function `get_tensor()` returns a copy of the tensor data.
# Use `tensor()` in order to get a pointer to the tensor.
output_data = interpreter.get_tensor(output_details[0]['index'])
print(output_data)
# Out:
# [{'name': 'input_1', 'index': 0, 'shape': array([ 1, 51]), 'shape_signature': array([-1, 51]), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# [[0.   0.02 0.   0.   0.98]]
